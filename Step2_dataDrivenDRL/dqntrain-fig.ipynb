# %%
from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
results = np.load('./Results_DQN_reward3/Results/Train1.npy',allow_pickle=True).tolist()

# %%
plt.figure(figsize = (15,8))
plt.plot(results['Episode_reward'],label='Training process of DQN')
plt.legend(fontsize=25)
plt.ylabel('The total sum of all the rewards',fontsize=25)
plt.xlabel('Epoch',fontsize=30)

plt.savefig('training.png',dpi=200)
